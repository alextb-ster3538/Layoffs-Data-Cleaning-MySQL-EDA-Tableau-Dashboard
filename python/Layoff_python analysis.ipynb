# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("layoffs_clean.csv", encoding='latin1', sep=';')

# %%
df.describe(include='all').T.round(2)
# Out:
#                         count unique            top  freq        mean  \
# company                  1991   1629           Loft     6         NaN
# location                 1991    169    SF Bay Area   526         NaN
# industry                 1991     30        Finance   239         NaN
# total_laid_off         1991.0    NaN            NaN   NaN  191.330487
# percentage_laid_off    1991.0    NaN            NaN   NaN    0.203304
# date                     1990    450     2020-04-02    24         NaN
# stage                    1986     16       Post-IPO   381         NaN
# country                  1991     51  United States  1274         NaN
# funds_raised_millions  1991.0    NaN            NaN   NaN  803.183827
#
#                                std  min   25%    50%    75%       max
# company                        NaN  NaN   NaN    NaN    NaN       NaN
# location                       NaN  NaN   NaN    NaN    NaN       NaN
# industry                       NaN  NaN   NaN    NaN    NaN       NaN
# total_laid_off          699.092461  0.0  17.0   55.0  138.0   12000.0
# percentage_laid_off       0.250664  0.0  0.04   0.12   0.25       1.0
# date                           NaN  NaN   NaN    NaN    NaN       NaN
# stage                          NaN  NaN   NaN    NaN    NaN       NaN
# country                        NaN  NaN   NaN    NaN    NaN       NaN
# funds_raised_millions  5780.228027  0.0  33.0  134.0  409.0  121900.0

# %%
stats = df['total_laid_off'].describe()

Q1 = stats['25%']
Q3 = stats['75%']
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['total_laid_off'] < lower_bound) | (df['total_laid_off'] > upper_bound)]
outliers.head()
# Out:
#          company       location     industry  total_laid_off  \
# 0      Atlassian         Sydney        Other             500
# 1       SiriusXM  New York City        Media             475
# 2         Alerzo         Ibadan       Retail             400
# 4           Loft      Sao Paulo  Real Estate             340
# 15  Thoughtworks        Chicago        Other             500
#
#     percentage_laid_off        date     stage        country  \
# 0                  0.05  2023-03-06  Post-IPO      Australia
# 1                  0.08  2023-03-06  Post-IPO  United States
# 2                  0.00  2023-03-06  Series B        Nigeria
# 4                  0.15  2023-03-03   Unknown         Brazil
# 15                 0.04  2023-03-01  Post-IPO  United States
#
#     funds_raised_millions
# 0                     210
# 1                     525
# 2                      16
# 4                     788
# 15                    748

# %%
outliers.to_csv("outliers_total_laid_off.csv", index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 2))
sns.boxplot(x=df['total_laid_off'], color="#4C72B0")
plt.title("Distribution of Total Layoffs (Boxplot)")
plt.xlabel("Total Laid Off")
plt.show()

# %%
stats = df['total_laid_off'].describe()
stats
# Out:
# count     1991.000000
# mean       191.330487
# std        699.092461
# min          0.000000
# 25%         17.000000
# 50%         55.000000
# 75%        138.000000
# max      12000.000000
# Name: total_laid_off, dtype: float64

# %%
len(outliers)
# Out:
# 212
